# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    362     34   John  January      Q1
# 1  2023-01-02       B   West    816     23   Mary  January      Q1
# 2  2023-01-03       C  North    375     21    Bob  January      Q1
# 3  2023-01-04       D  South    354     28  Alice  January      Q1
# 4  2023-01-05       A   East    628     30   John  January      Q1
# 5  2023-01-06       B   West    651     81   Mary  January      Q1
# 6  2023-01-07       C  North    239     97    Bob  January      Q1
# 7  2023-01-08       D  South    800     63  Alice  January      Q1
# 8  2023-01-09       A   East    695     28   John  January      Q1
# 9  2023-01-10       B   West    204     99   Mary  January      Q1
# 10 2023-01-11       C  North    849     41    Bob  January      Q1
# 11 2023-01-12       D  South    893     59  Alice  January      Q1
# 12 2023-01-13       A   East    291     77   John  January      Q1
# 13 2023-01-14       B   West    900     35   Mary  January      Q1
# 14 2023-01-15       C  North    160     81    Bob  January      Q1
# 15 2023-01-16       D  South    815     90  Alice  January      Q1
# 16 2023-01-17       A   East    122     22   John  January      Q1
# 17 2023-01-18       B   West    367     92   Mary  January      Q1
# 18 2023-01-19       C  North    240     67    Bob  January      Q1
# 19 2023-01-20       D  South    974     73  Alice  January      Q1

# %%
pd.pivot_table(df,values = "Sales",index= 'Region',columns= "Product",aggfunc = "median")
# Out:
# Product      A      B      C      D
# Region
# East     362.0    NaN    NaN    NaN
# North      NaN    NaN  240.0    NaN
# South      NaN    NaN    NaN  815.0
# West       NaN  651.0    NaN    NaN

# %%
pd.pivot_table(df,values = ["Sales","Units"],index= 'Region',columns= "Product")
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     419.6    NaN    NaN    NaN  38.2   NaN   NaN   NaN
# North      NaN    NaN  372.6    NaN   NaN   NaN  61.4   NaN
# South      NaN    NaN    NaN  767.2   NaN   NaN   NaN  62.6
# West       NaN  587.6    NaN    NaN   NaN  66.0   NaN   NaN

# %%
pd.crosstab(df["Region"],df["Product"])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
